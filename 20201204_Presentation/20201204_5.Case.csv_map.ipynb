# %%
import pandas as pd

Case = pd.read_csv("C:/Users/HOME/Desktop/수DA쟁이/20201127_TEAMPROJECT_4/코로나19/coronavirusdataset_20200601/Case.csv")
Case.head()
# Out:
#    case_id province           city  group                 infection_case  \
# 0  1000001    Seoul     Yongsan-gu   True                  Itaewon Clubs
# 1  1000002    Seoul        Guro-gu   True            Guro-gu Call Center
# 2  1000003    Seoul  Dongdaemun-gu   True                  Dongan Church
# 3  1000004    Seoul        Guro-gu   True          Manmin Central Church
# 4  1000005    Seoul   Eunpyeong-gu   True  Eunpyeong St. Mary's Hospital
#
#    confirmed   latitude   longitude
# 0      133.0  37.538621  126.992652
# 1       99.0  37.508163  126.884387
# 2       20.0  37.592888  127.056766
# 3       41.0  37.481059  126.894343
# 4       14.0   37.63369    126.9165

# %%
import numpy as np
#Case['p'] = np.nan
Case['province'][Case['province']=="Seoul"]="서울"
Case['province'][Case['province']=="Busan"]="부산"
Case['province'][Case['province']=="Chungcheongbuk-do"]="충청북도"
Case['province'][Case['province']=="Chungcheongnam-do"]="충청남도"
Case['province'][Case['province']=="Daegu"]="대구"
Case['province'][Case['province']=="Daejeon"]="대전"
Case['province'][Case['province']=="Gangwon-do"]="강원도"
Case['province'][Case['province']=="Gwangju"]="광주"
Case['province'][Case['province']=="Gyeonggi-do"]="경기도"
Case['province'][Case['province']=="Gyeongsangnam-do"]="경상남도"
Case['province'][Case['province']=="Gyeongsangbuk-do"]="경상북도"
Case['province'][Case['province']=="Incheon"]="인천"
Case['province'][Case['province']=="Jeju-do"]="제주도"
Case['province'][Case['province']=="Jeollabuk-do"]="전라북도"
Case['province'][Case['province']=="Jeollanam-do"]="전라남도"
Case['province'][Case['province']=="Sejong"]="세종"
Case['province'][Case['province']=="Ulsan"]="울산"
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
Case.head(2)
# Out:
#    case_id province        city  group       infection_case  confirmed  \
# 0  1000001       서울  Yongsan-gu   True        Itaewon Clubs      133.0
# 1  1000002       서울     Guro-gu   True  Guro-gu Call Center       99.0
#
#     latitude   longitude
# 0  37.538621  126.992652
# 1  37.508163  126.884387

# %%
Case['province'].unique()
# Out:
# array(['서울', '부산', '대구', '광주', '인천', '대전', '울산', '세종', '경기도', '강원도',
#        '충청북도', '충청남도', '전라북도', '전라남도', '경상북도', '경상남도', '제주도'],
#       dtype=object)

# %%
Case['province'][Case['province'].isin(['Seoul'])]="서울"
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Case
# Out:
#      case_id province             city  group                 infection_case  \
# 0    1000001       서울       Yongsan-gu   True                  Itaewon Clubs
# 1    1000002       서울          Guro-gu   True            Guro-gu Call Center
# 2    1000003       서울    Dongdaemun-gu   True                  Dongan Church
# 3    1000004       서울          Guro-gu   True          Manmin Central Church
# 4    1000005       서울     Eunpyeong-gu   True  Eunpyeong St. Mary's Hospital
# ..       ...      ...              ...    ...                            ...
# 123  6100010     경상남도                -  False                            etc
# 124  7000001      제주도                -  False                overseas inflow
# 125  7000002      제주도                -  False           contact with patient
# 126  7000003      제주도                -  False                            etc
# 127  7000004      제주도  from other city   True                  Itaewon Clubs
#
#      confirmed   latitude   longitude
# ...

# %%
Case.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   case_id         128 non-null    int64
#  1   province        128 non-null    object
#  2   city            128 non-null    object
#  3   group           128 non-null    bool
#  4   infection_case  128 non-null    object
#  5   confirmed       125 non-null    float64
#  6   latitude        128 non-null    object
#  7   longitude       128 non-null    object
# dtypes: bool(1), float64(1), int64(1), object(5)
# memory usage: 7.2+ KB

# %%
Case['city'][Case['city']=="Bonghwa-gun"]="봉화군"
Case['city'][Case['city']=="Bucheon-si"]="부천시"
Case['city'][Case['city']=="Changnyeong-gun"]="창녕군"
Case['city'][Case['city']=="Changwon-si"]="창원시"
Case['city'][Case['city']=="Cheonan-si"]="천안시"
Case['city'][Case['city']=="Cheongdo-gun"]="청도군"
Case['city'][Case['city']=="Chilgok-gun"]="칠곡군"
Case['city'][Case['city']=="Dalseong-gun"]="달서군"
Case['city'][Case['city']=="Dongdaemun-gu"]="동대문구"
Case['city'][Case['city']=="Dong-gu"]="동구"
Case['city'][Case['city']=="Dongnae-gu"]="동래구"
Case['city'][Case['city']=="Eunpyeong-gu"]="은평구"
Case['city'][Case['city']=="from other city"]="등등"
Case['city'][Case['city']=="form other city"]="등등"
Case['city'][Case['city']=="Gangnam-gu"]="강남구"
Case['city'][Case['city']=="Geochang-gun"]="거창군"
Case['city'][Case['city']=="Goesan-gun"]="괴산군"
Case['city'][Case['city']=="Guro-gu"]="구로구"
Case['city'][Case['city']=="Gyeongsan-si"]="경산시"
Case['city'][Case['city']=="Haeundae-gu"]="해운대구"
Case['city'][Case['city']=="Jin-gu"]="진구"
Case['city'][Case['city']=="Jinju-si"]="진주시"
Case['city'][Case['city']=="Jongno-gu"]="종로구"
Case['city'][Case['city']=="Jung-gu"]="정구"
Case['city'][Case['city']=="Muan-gun"]="무안군"
Case['city'][Case['city']=="Nam-gu"]="남구"
Case['city'][Case['city']=="Sejong"]="세종"
Case['city'][Case['city']=="Seodaemun-gu"]="서대문구"
Case['city'][Case['city']=="Seo-gu"]="서구"
Case['city'][Case['city']=="Seongdong-gu"]="성동구"
Case['city'][Case['city']=="Seosan-si"]="서산시"
Case['city'][Case['city']=="Seongnam-si"]="성남시"
Case['city'][Case['city']=="Suwon-si"]="수원시"
Case['city'][Case['city']=="Suyeong-gu"]="수영구"
Case['city'][Case['city']=="Uijeongbu-si"]="의정부시"
Case['city'][Case['city']=="Wonju-si"]="원주시"
Case['city'][Case['city']=="Yechun-gun"]="예천군"
Case['city'][Case['city']=="Yeongdeungpo-gu"]="영등포구"
Case['city'][Case['city']=="Yongsan-gu"]="영산구"
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
Case['city'].unique()
# Out:
# array(['영산구', '구로구', '동대문구', '은평구', '성동구', '종로구', '강남구', '정구', '서대문구',
#        '등등', '영등포구', '-', '동래구', '수영구', '해운대구', '진구', '남구', '달서군', '서구',
#        '동구', '세종', '부천시', '성남시', '의정부시', '수원시', '원주시', '괴산군', '천안시',
#        '서산시', '무안군', '청도군', '봉화군', '칠곡군', '경산시', '예천군', '거창군', '진주시',
#        '창원시', '창녕군'], dtype=object)

# %%
Case.head(2)
# Out:
#    case_id province city  group       infection_case  confirmed   latitude  \
# 0  1000001       서울  영산구   True        Itaewon Clubs      133.0  37.538621
# 1  1000002       서울  구로구   True  Guro-gu Call Center       99.0  37.508163
#
#     longitude
# 0  126.992652
# 1  126.884387

# %%
text = Case['province'] == 'Seoul'
text.replace("False",)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 123    False
# 124    False
# 125    False
# 126    False
# 127    False
# Name: province, Length: 128, dtype: bool

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

Case['group'].value_counts().plot(kind='bar',color='skyblue')
plt.xticks(rotation = - 0 ) # x축 텍스트 회전하기
# Out:
# (array([0, 1]), <a list of 2 Text xticklabel objects>)

# %% [markdown]
# #### 지도로 나타내기

# %%
df = Case['group']

# %%
dodo = Case[['latitude','longitude','infection_case']]
dodo
# Out:
#       latitude   longitude                 infection_case
# 0    37.538621  126.992652                  Itaewon Clubs
# 1    37.508163  126.884387            Guro-gu Call Center
# 2    37.592888  127.056766                  Dongan Church
# 3    37.481059  126.894343          Manmin Central Church
# 4     37.63369    126.9165  Eunpyeong St. Mary's Hospital
# ..         ...         ...                            ...
# 123          -           -                            etc
# 124          -           -                overseas inflow
# 125          -           -           contact with patient
# 126          -           -                            etc
# 127          -           -                  Itaewon Clubs
#
# [128 rows x 3 columns]

# %%
dodo.isnull().sum()
# Out:
# latitude     0
# longitude    0
# dtype: int64

# %%
import numpy as np
dodo = dodo.replace("-", np.nan)

# %%
dodo = dodo.dropna()
dodo
# Out:
#       latitude   longitude
# 0    37.538621  126.992652
# 1    37.508163  126.884387
# 2    37.592888  127.056766
# 3    37.481059  126.894343
# 4     37.63369    126.9165
# ..         ...         ...
# 115   35.68556    127.9127
# 116  35.805681  127.917805
# 117  35.164845  128.126969
# 118   35.22115    128.6866
# 119   35.54127    128.5008
#
# [47 rows x 2 columns]

# %%
# 데이터 프레임 볼 수 있는거 하기
pd.set_option('display.max_row', 10)
pd.set_option('display.max_columns', 10)

# %%
dodo
# Out:
#       latitude   longitude
# 0    37.538621  126.992652
# 1    37.508163  126.884387
# 2    37.592888  127.056766
# 3    37.481059  126.894343
# 4     37.63369    126.9165
# ..         ...         ...
# 115   35.68556    127.9127
# 116  35.805681  127.917805
# 117  35.164845  128.126969
# 118   35.22115    128.6866
# 119   35.54127    128.5008
#
# [47 rows x 2 columns]

# %%
dodo['infection_case'] = Case['infection_case']

# %%
dodo = dodo.reset_index()
del dodo['index']

# %%
dodo
# Out:
#      latitude   longitude                 infection_case
# 0   37.538621  126.992652                  Itaewon Clubs
# 1   37.508163  126.884387            Guro-gu Call Center
# 2   37.592888  127.056766                  Dongan Church
# 3   37.481059  126.894343          Manmin Central Church
# 4    37.63369    126.9165  Eunpyeong St. Mary's Hospital
# ..        ...         ...                            ...
# 42   35.68556    127.9127                Geochang Church
# 43  35.805681  127.917805   Geochang-gun Woongyang-myeon
# 44  35.164845  128.126969                    Wings Tower
# 45   35.22115    128.6866     Hanmaeum Changwon Hospital
# 46   35.54127    128.5008       Changnyeong Coin Karaoke
#
# [47 rows x 3 columns]

# %%
dodo['infection_case'][dodo['infection_case']=='Itaewon Clubs'] = "이태원 클럽"

# %%
dodo
# Out:
#      latitude   longitude                 infection_case
# 0   37.538621  126.992652                         이태원 클럽
# 1   37.508163  126.884387            Guro-gu Call Center
# 2   37.592888  127.056766                  Dongan Church
# 3   37.481059  126.894343          Manmin Central Church
# 4    37.63369    126.9165  Eunpyeong St. Mary's Hospital
# ..        ...         ...                            ...
# 42   35.68556    127.9127                Geochang Church
# 43  35.805681  127.917805   Geochang-gun Woongyang-myeon
# 44  35.164845  128.126969                    Wings Tower
# 45   35.22115    128.6866     Hanmaeum Changwon Hospital
# 46   35.54127    128.5008       Changnyeong Coin Karaoke
#
# [47 rows x 3 columns]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %config InlineBackend.figure_format = 'retina'
 
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

# %%
import folium
map = folium.Map(location=[37.5, 127], zoom_start=12)

# %%
for item in dodo.index:
    lat = dodo.loc[item, 'latitude']
    long = dodo.loc[item, 'longitude']
    folium.CircleMarker([lat, long],
                        #radius=Case.loc[item, 'confirmed'],
                        popup=dodo.loc[item, 'infection_case'],
                        color = 'red',
                        fill = True).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
